# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:38703")
client

# %%
from dask.distributed import Client

client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:36495' processes=4 threads=8, memory=16.68 GB>

# %%
import dask.array as da

x = da.random.random((100000, 100000), chunks="1000 MiB")
x = da.exp(x).sum(axis=0).mean()
x.compute()
# Out:
# 171828.38874389156
