# %%
from fastai import *
from fastai.vision import *

import warnings
warnings.filterwarnings('ignore', message='Default grid_sample and affine_grid behavior will be changed ')

# %%
path = Path('/home/kushaj/Desktop/Data/')
train_path = path/'trashdata/'
test_path = path/'trashtest'

print(train_path.ls())
print(test_path.ls())
# Out:
# [PosixPath('/home/kushaj/Desktop/Data/trashdata/metal'), PosixPath('/home/kushaj/Desktop/Data/trashdata/glass'), PosixPath('/home/kushaj/Desktop/Data/trashdata/paper'), PosixPath('/home/kushaj/Desktop/Data/trashdata/.DS_Store'), PosixPath('/home/kushaj/Desktop/Data/trashdata/cardboard'), PosixPath('/home/kushaj/Desktop/Data/trashdata/models'), PosixPath('/home/kushaj/Desktop/Data/trashdata/plastic')]
# [PosixPath('/home/kushaj/Desktop/Data/trashtest/metal'), PosixPath('/home/kushaj/Desktop/Data/trashtest/glass'), PosixPath('/home/kushaj/Desktop/Data/trashtest/paper'), PosixPath('/home/kushaj/Desktop/Data/trashtest/cardboard'), PosixPath('/home/kushaj/Desktop/Data/trashtest/plastic')]

# %%
src = (ImageList.from_folder(train_path)
                .split_by_rand_pct()
                .label_from_folder())

data = (src.transform(get_transforms(flip_vert=True), size=(128, 128))
           .databunch(bs=32, val_bs=32, num_workers=8)
           .normalize(imagenet_stats))

data_test = (ImageList.from_folder(test_path)
                      .split_none()
                      .label_from_folder()
                      .transform(size=(256, 256))
                      .databunch(num_workers=8, val_bs=32)
                      .normalize(imagenet_stats))

data_test.valid_dl = data_test.train_dl
data_test.train_dl = None

# %%
data.show_batch(figsize=(6,6))

# %%
# data_test.show_batch(figsize=(6,6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fcc4b8fad6bd> in <module>
# ----> 1 data_test.show_batch(figsize=(6,6))
#
# NameError: name 'data_test' is not defined

# %%
learn = cnn_learner(data, models.densenet121, metrics=[accuracy], callback_fns=ShowGraph)

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(10, max_lr=1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.045155</td>
#       <td>0.555165</td>
#       <td>0.815421</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.846658</td>
#       <td>1.087626</td>
#       <td>0.714953</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.804697</td>
#       <td>0.863775</td>
#       <td>0.752336</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.748367</td>
#       <td>0.907256</td>
#       <td>0.764019</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.664330</td>
#       <td>0.541281</td>
#       <td>0.848131</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(20, max_lr=5e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.114794</td>
#       <td>0.266917</td>
#       <td>0.936916</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.135077</td>
#       <td>0.250001</td>
#       <td>0.936916</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.130298</td>
#       <td>0.234744</td>
#       <td>0.946262</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.123456</td>
#       <td>0.255260</td>
#       <td>0.929907</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.126828</td>
#       <td>0.260219</td>
#       <td>0.934579</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
data = (src.transform(get_transforms(flip_vert=True), size=(256, 256))
           .databunch(num_workers=8, bs=16)
           .normalize(imagenet_stats))

# %%
# learn.load(train_path/'models'/'second')

learn.data = data

# %%
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(10, max_lr=1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.292817</td>
#       <td>0.279815</td>
#       <td>0.922897</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.308027</td>
#       <td>0.266992</td>
#       <td>0.925234</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.297709</td>
#       <td>0.263119</td>
#       <td>0.927570</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.226148</td>
#       <td>0.256468</td>
#       <td>0.927570</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.260765</td>
#       <td>0.248104</td>
#       <td>0.922897</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot(skip_start=0)

# %%
learn.save('freeze_256')

# %%
learn.fit_one_cycle(5, max_lr=1e-7)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.221385</td>
#       <td>0.238865</td>
#       <td>0.932243</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.236753</td>
#       <td>0.240988</td>
#       <td>0.929907</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.220542</td>
#       <td>0.243000</td>
#       <td>0.929907</td>
#       <td>01:36</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.237480</td>
#       <td>0.267353</td>
#       <td>0.922897</td>
#       <td>01:43</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.241284</td>
#       <td>0.260459</td>
#       <td>0.927570</td>
#       <td>01:45</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('densenet_unfreeze_256')

# %%
learn.load('densenet_unfreeze_256')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (1712 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# metal,metal,metal,metal,metal
# Path: /home/kushaj/Desktop/Data/trashdata;
#
# Valid: LabelList (428 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# glass,glass,cardboard,glass,cardboard
# Path: /home/kushaj/Desktop/Data/trashdata;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace=True)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
# ...

# %%
learn.validate(dl=data_test.valid_dl)
# Out:
# [0.16246195, tensor(0.9375)]
